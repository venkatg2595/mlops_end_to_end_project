# %%
import os

# %%
# python configox

d = {"key1": "value1", "key2": "value2"}

# %%
d['key1']
# Out:
# 'value1'

# %%
d.items
# Out:
# <function dict.items()>

# %%
from box import ConfigBox
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 from box import ConfigBox
#
# File c:\Users\Admin\anaconda3\envs\mlproject\Lib\site-packages\box\__init__.py:1
# ----> 1 from .client import BoxClient, \
#       2     start_authenticate_v1, finish_authenticate_v1, \
#       3     start_authenticate_v2, finish_authenticate_v2, refresh_v2_token, \
#       4     CredentialsV1, CredentialsV2
#       6 from .client import EventFilter, EventType, ShareAccess
#       7 from .client import BoxClientException, BoxAccountUnauthorized, BoxAuthenticationException, PreconditionFailed, \
#       8     ItemDoesNotExist, ItemAlreadyExists
#
# File c:\Users\Admin\anaconda3\envs\mlproject\Lib\site-packages\box\client.py:7
#       1 """
#       2 A client library for working with Box's v2 API.
#       3 For extended specs, see: http://developers.box.com/docs/
#       4 """
#       5 from datetime import datetime
# ----> 7 from httplib import NOT_FOUND, PRECONDITION_FAILED, CONFLICT, UNAUTHORIZED
#       8 import json
#       9 import time
#
# ModuleNotFoundError: No module named 'httplib'

# %%
# !pip install box.py
# Out:
# Requirement already satisfied: box.py in c:\users\admin\anaconda3\envs\mlproject\lib\site-packages (1.2.8)
# Requirement already satisfied: requests>=1.0.0 in c:\users\admin\anaconda3\envs\mlproject\lib\site-packages (from box.py) (2.32.3)
# Requirement already satisfied: lxml>=3.0 in c:\users\admin\anaconda3\envs\mlproject\lib\site-packages (from box.py) (5.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\anaconda3\envs\mlproject\lib\site-packages (from requests>=1.0.0->box.py) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\envs\mlproject\lib\site-packages (from requests>=1.0.0->box.py) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda3\envs\mlproject\lib\site-packages (from requests>=1.0.0->box.py) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\envs\mlproject\lib\site-packages (from requests>=1.0.0->box.py) (2025.1.31)

# %%
from box import ConfigBox
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 from box import ConfigBox
#
# File c:\Users\Admin\anaconda3\envs\mlproject\Lib\site-packages\box\__init__.py:1
# ----> 1 from .client import BoxClient, \
#       2     start_authenticate_v1, finish_authenticate_v1, \
#       3     start_authenticate_v2, finish_authenticate_v2, refresh_v2_token, \
#       4     CredentialsV1, CredentialsV2
#       6 from .client import EventFilter, EventType, ShareAccess
#       7 from .client import BoxClientException, BoxAccountUnauthorized, BoxAuthenticationException, PreconditionFailed, \
#       8     ItemDoesNotExist, ItemAlreadyExists
#
# File c:\Users\Admin\anaconda3\envs\mlproject\Lib\site-packages\box\client.py:7
#       1 """
#       2 A client library for working with Box's v2 API.
#       3 For extended specs, see: http://developers.box.com/docs/
#       4 """
#       5 from datetime import datetime
# ----> 7 from httplib import NOT_FOUND, PRECONDITION_FAILED, CONFLICT, UNAUTHORIZED
#       8 import json
#       9 import time
#
# ModuleNotFoundError: No module named 'httplib'

# %%
from box import ConfigBox
from datetime import datetime
from httplib import NOT_FOUND, PRECONDITION_FAILED, CONFLICT, UNAUTHORIZED
import json
import time
print("ConfigBox imported successfully!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 from box import ConfigBox
#       2 from datetime import datetime
#       3 from httplib import NOT_FOUND, PRECONDITION_FAILED, CONFLICT, UNAUTHORIZED
#
# File c:\Users\Admin\anaconda3\envs\mlproject\Lib\site-packages\box\__init__.py:1
# ----> 1 from .client import BoxClient, \
#       2     start_authenticate_v1, finish_authenticate_v1, \
#       3     start_authenticate_v2, finish_authenticate_v2, refresh_v2_token, \
#       4     CredentialsV1, CredentialsV2
#       6 from .client import EventFilter, EventType, ShareAccess
#       7 from .client import BoxClientException, BoxAccountUnauthorized, BoxAuthenticationException, PreconditionFailed, \
#       8     ItemDoesNotExist, ItemAlreadyExists
#
# File c:\Users\Admin\anaconda3\envs\mlproject\Lib\site-packages\box\client.py:7
#       1 """
#       2 A client library for working with Box's v2 API.
#       3 For extended specs, see: http://developers.box.com/docs/
#       4 """
#       5 from datetime import datetime
# ----> 7 from httplib import NOT_FOUND, PRECONDITION_FAILED, CONFLICT, UNAUTHORIZED
#       8 import json
#       9 import time
#
# ModuleNotFoundError: No module named 'httplib'

# %%
pip show box
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Package(s) not found: box

# %%
pip uninstall box
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping box as it is not installed.

# %%
pip install box.py
# Out:
# Requirement already satisfied: box.py in c:\users\admin\anaconda3\envs\mlproject\lib\site-packages (1.2.8)
# Requirement already satisfied: requests>=1.0.0 in c:\users\admin\anaconda3\envs\mlproject\lib\site-packages (from box.py) (2.32.3)
# Requirement already satisfied: lxml>=3.0 in c:\users\admin\anaconda3\envs\mlproject\lib\site-packages (from box.py) (5.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\anaconda3\envs\mlproject\lib\site-packages (from requests>=1.0.0->box.py) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\envs\mlproject\lib\site-packages (from requests>=1.0.0->box.py) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda3\envs\mlproject\lib\site-packages (from requests>=1.0.0->box.py) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\envs\mlproject\lib\site-packages (from requests>=1.0.0->box.py) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge box.py
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed
#
# Note: you may need to restart the kernel to use updated packages.
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - box.py
#
# Current channels:
#
#   - https://conda.anaconda.org/conda-forge
#   - defaults
#   - https://repo.anaconda.com/pkgs/main
#   - https://repo.anaconda.com/pkgs/r
#   - https://repo.anaconda.com/pkgs/msys2
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.

# %%
conda activate mlproject
# Out:
# Note: you may need to restart the kernel to use updated packages.
# CondaError: Run 'conda init' before 'conda activate'

# %%
conda activate mlproject
# Out:
# Note: you may need to restart the kernel to use updated packages.
# CondaError: Run 'conda init' before 'conda activate'

# %%
conda info --envs
# Out:
# # conda environments:
# #
#                          C:\Users\Admin\AppData\Local\anaconda3
# base                     C:\Users\Admin\anaconda3
# mlproject             *  C:\Users\Admin\anaconda3\envs\mlproject
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show box.py
# Out:
# Name: box.py
# Version: 1.2.8
# Summary: Python client for Box
# Home-page: http://github.com/sookasa/box.py
# Author: Sookasa
# Author-email: dev@sookasa.com
# License: BSD
# Location: c:\Users\Admin\anaconda3\envs\mlproject\Lib\site-packages
# Requires: lxml, requests
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
from http.client import NOT_FOUND, PRECONDITION_FAILED, CONFLICT, UNAUTHORIZED

# %%
import json
print('JSON module is working!')
# Out:
# JSON module is working!

# %%
from box import ConfigBox
d2 = ConfigBox({"key1": "value1", "key2": "value2"})
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 from box import ConfigBox
#       2 d2 = ConfigBox({"key1": "value1", "key2": "value2"})
#
# File c:\Users\Admin\anaconda3\envs\mlproject\Lib\site-packages\box\__init__.py:1
# ----> 1 from .client import BoxClient, \
#       2     start_authenticate_v1, finish_authenticate_v1, \
#       3     start_authenticate_v2, finish_authenticate_v2, refresh_v2_token, \
#       4     CredentialsV1, CredentialsV2
#       6 from .client import EventFilter, EventType, ShareAccess
#       7 from .client import BoxClientException, BoxAccountUnauthorized, BoxAuthenticationException, PreconditionFailed, \
#       8     ItemDoesNotExist, ItemAlreadyExists
#
# File c:\Users\Admin\anaconda3\envs\mlproject\Lib\site-packages\box\client.py:7
#       1 """
#       2 A client library for working with Box's v2 API.
#       3 For extended specs, see: http://developers.box.com/docs/
#       4 """
#       5 from datetime import datetime
# ----> 7 from httplib import NOT_FOUND, PRECONDITION_FAILED, CONFLICT, UNAUTHORIZED
#       8 import json
#       9 import time
#
# ModuleNotFoundError: No module named 'httplib'

# %%
pip uninstall box.py

# %%
pip uninstall box
